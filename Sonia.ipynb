# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %%
#loading the dataset
file="Sensorimotor_norms_29Jan2024.csv"
Lancaster_norms = pd.read_csv(file, sep=",")
Lancaster_norms
# Out:
#              Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 0               A          2.214           0.000        0.429
# 1      A CAPPELLA          4.333           0.000        0.222
# 2        AARDVARK          1.625           0.562        1.625
# 3           ABACK          1.294           0.059        0.294
# 4          ABACUS          1.556           0.167        3.722
# ...           ...            ...             ...          ...
# 39702        ZOOM          1.050           0.000        0.400
# 39703     ZOOM IN          0.474           0.105        0.316
# 39704   ZOOM LENS          0.556           0.000        1.111
# 39705   ZOOPHOBIA          1.714           0.286        0.857
# 39706    ZUCCHINI          0.000           4.778        2.778
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  Foot_leg.mean  \
# 0                   0.000           0.000        2.429          0.000
# 1                   0.722           0.000        1.667          0.381
# 2                   0.062           1.250        4.125          0.176
# 3                   1.353           0.000        2.824          0.000
# 4                   0.278           0.111        3.944          0.000
# ...                   ...             ...          ...            ...
# 39702               0.800           0.000        3.800          1.263
# 39703               0.158           0.105        3.789          0.300
# 39704               0.278           0.000        3.444          0.053
# 39705               3.000           0.571        3.071          0.800
# 39706               0.667           2.222        4.444          0.000
#
#        Hand_arm.mean  Head.mean  ...  Max_strength.sensorimotor  \
# 0              0.357      1.071  ...                      2.429
# 1              0.429      2.714  ...                      4.333
# 2              0.706      2.235  ...                      4.125
# 3              0.000      3.273  ...                      3.273
# 4              2.474      2.632  ...                      3.944
# ...              ...        ...  ...                        ...
# 39702          1.474      2.632  ...                      3.800
# 39703          1.650      3.150  ...                      3.789
# 39704          1.789      3.421  ...                      3.444
# 39705          0.800      2.267  ...                      3.071
# 39706          1.600      1.300  ...                      4.778
#
#        Exclusivity.sensorimotor  Dominant.sensorimotor  Minkowski3.perceptual  \
# 0                         0.354                 Visual                  2.934
# 1                         0.285               Auditory                  4.421
# 2                         0.326                 Visual                  4.325
# 3                         0.339                   Head                  3.007
# 4                         0.263                 Visual                  4.887
# ...                         ...                    ...                    ...
# 39702                     0.289                 Visual                  3.840
# 39703                     0.349                 Visual                  3.793
# 39704                     0.310                 Visual                  3.488
# 39705                     0.186                 Visual                  3.955
# 39706                     0.224              Gustatory                  6.123
#
#        Minkowski3.action  Minkowski3.sensorimotor  N_known.perceptual  \
# 0                  1.097                    2.984                  14
# 1                  4.167                    5.415                  18
# 2                  2.259                    4.521                  16
# 3                  3.274                    3.964                  17
# 4                  3.219                    5.314                  18
# ...                  ...                      ...                 ...
# 39702              2.914                    4.333                  20
# 39703              3.296                    4.488                  19
# 39704              3.578                    4.452                  18
# 39705              2.392                    4.227                  14
# 39706              3.394                    6.452                  18
#
#        Percent_known.perceptual  N_known.action  Percent_known.action
# 0                         0.737              14                 0.667
# 1                         0.947              21                 1.000
# 2                         0.889              17                 0.850
# 3                         0.850              11                 0.579
# 4                         0.947              19                 0.905
# ...                         ...             ...                   ...
# 39702                     1.000              19                 1.000
# 39703                     1.000              20                 1.000
# 39704                     1.000              19                 1.000
# 39705                     0.778              15                 0.750
# 39706                     1.000              20                 0.952
#
# [39707 rows x 39 columns]

# %%
#selecting columns
column=["Word","Auditory.mean","Gustatory.mean","Haptic.mean","Interoceptive.mean","Olfactory.mean","Visual.mean"]
sensory_dimentions_norms=pd.DataFrame(Lancaster_norms,columns=column)
sensory_dimentions_norms
# Out:
#              Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 0               A          2.214           0.000        0.429
# 1      A CAPPELLA          4.333           0.000        0.222
# 2        AARDVARK          1.625           0.562        1.625
# 3           ABACK          1.294           0.059        0.294
# 4          ABACUS          1.556           0.167        3.722
# ...           ...            ...             ...          ...
# 39702        ZOOM          1.050           0.000        0.400
# 39703     ZOOM IN          0.474           0.105        0.316
# 39704   ZOOM LENS          0.556           0.000        1.111
# 39705   ZOOPHOBIA          1.714           0.286        0.857
# 39706    ZUCCHINI          0.000           4.778        2.778
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean
# 0                   0.000           0.000        2.429
# 1                   0.722           0.000        1.667
# 2                   0.062           1.250        4.125
# 3                   1.353           0.000        2.824
# 4                   0.278           0.111        3.944
# ...                   ...             ...          ...
# 39702               0.800           0.000        3.800
# 39703               0.158           0.105        3.789
# 39704               0.278           0.000        3.444
# 39705               3.000           0.571        3.071
# 39706               0.667           2.222        4.444
#
# [39707 rows x 7 columns]

# %%
#sorting
visual_sorted=sensory_dimentions_norms.sort_values(by= ["Visual.mean"],ascending=False)
visual_sorted
# Out:
#                   Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 33            ABNORMAL          1.895           1.263        2.000
# 3691            BOUGHT          2.000           0.444        2.167
# 5488             CIGAR          0.579           3.000        2.263
# 26936             PULP          0.278           3.222        2.333
# 10311            DRANK          1.500           3.643        2.071
# ...                ...            ...             ...          ...
# 1067            ANALLY          0.312           0.188        2.000
# 8949   DESENSITIZATION          1.889           1.278        2.000
# 35600          TUGGING          0.562           0.000        2.312
# 27865           REDIAL          1.789           0.000        2.211
# 5754          CLITORAL          0.231           1.462        2.077
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  visual.mask  \
# 33                  2.053           1.526          3.0          3.0
# 3691                0.611           0.389          3.0          3.0
# 5488                0.789           3.737          3.0          3.0
# 26936               0.500           0.944          3.0          3.0
# 10311               3.357           1.000          3.0          3.0
# ...                   ...             ...          ...          ...
# 1067                2.062           0.812          2.0          2.0
# 8949                3.000           1.500          2.0          2.0
# 35600               1.312           0.188          2.0          2.0
# 27865               0.474           0.000          2.0          2.0
# 5754                1.923           0.538          2.0          2.0
#
#        haptic.mask
# 33           2.000
# 3691         2.167
# 5488         2.263
# 26936        2.333
# 10311        2.071
# ...            ...
# 1067         2.000
# 8949         2.000
# 35600        2.312
# 27865        2.211
# 5754         2.077
#
# [828 rows x 9 columns]

# %%
#sorting
haptic_sorted = sensory_dimentions_norms.sort_values(by = ["Haptic.mean"],ascending=False)
haptic_sorted
# Out:
#               Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 26414       PRICKS          0.833           0.000          3.0
# 19969  LIGHTWEIGHT          0.464           0.071          3.0
# 2630       BEATING          2.263           0.421          3.0
# 21836      MOISTLY          0.438           1.375          3.0
# 15699   HEADPHONES          4.706           0.000          3.0
# ...            ...            ...             ...          ...
# 20135   LIVERWURST          0.765           3.824          2.0
# 21201      MENDING          0.389           0.000          2.0
# 21202        MENDS          1.533           0.000          2.0
# 21855     MOLESKIN          0.133           0.000          2.0
# 33        ABNORMAL          1.895           1.263          2.0
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  visual.mask  \
# 26414               1.611           0.000        2.667        2.667
# 19969               1.036           0.000        2.429        2.429
# 2630                2.737           0.421        2.842        2.842
# 21836               1.125           0.688        2.125        2.125
# 15699               1.176           0.059        2.471        2.471
# ...                   ...             ...          ...          ...
# 20135               1.059           3.294        2.882        2.882
# 21201               0.333           0.167        2.944        2.944
# 21202               1.267           0.000        2.933        2.933
# 21855               0.200           0.333        2.533        2.533
# 33                  2.053           1.526        3.000        3.000
#
#        haptic.mask
# 26414          3.0
# 19969          3.0
# 2630           3.0
# 21836          3.0
# 15699          3.0
# ...            ...
# 20135          2.0
# 21201          2.0
# 21202          2.0
# 21855          2.0
# 33             2.0
#
# [828 rows x 9 columns]

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#the-where-method-and-masking
# - df.where is not asking where in a location sense but in a "take the data *where* it falls under a specific parameter"

# %%
sensory_dimentions_norms['visual.mask']= sensory_dimentions_norms['Visual.mean'][(sensory_dimentions_norms['Visual.mean']<= 3)& (sensory_dimentions_norms['Visual.mean']>=2)] 
sensory_dimentions_norms
# Out:
# /var/folders/tx/v15j42jn0y5dmzxnl_jrnhz80000gn/T/ipykernel_27007/3295190060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sensory_dimentions_norms['visual.mask']= sensory_dimentions_norms['Visual.mean'][(sensory_dimentions_norms['Visual.mean']<= 3)&(sensory_dimentions_norms['Visual.mean']>=2)]
#              Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 33       ABNORMAL          1.895           1.263        2.000
# 102    ABSORBENCY          0.158           0.053        2.211
# 107    ABSORPTION          0.714           0.714        2.286
# 280       ACQUIRE          0.824           0.647        2.176
# 380    ADHESIVELY          0.500           0.455        2.909
# ...           ...            ...             ...          ...
# 39538       WRUNG          0.875           0.000        2.188
# 39556        YANK          1.400           0.450        2.700
# 39637  YOURSELVES          2.474           1.316        2.421
# 39653         ZAP          2.100           0.050        2.750
# 39687        ZIPS          2.267           0.200        2.133
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  visual.mask  \
# 33                  2.053           1.526        3.000        3.000
# 102                 0.316           0.211        2.526        2.526
# 107                 2.071           0.357        3.000        3.000
# 280                 1.000           0.588        2.824        2.824
# 380                 0.182           0.318        2.000        2.000
# ...                   ...             ...          ...          ...
# 39538               0.125           0.000        2.375        2.375
# 39556               1.200           0.550        2.900        2.900
# 39637               2.737           1.737        3.000        3.000
# 39653               2.200           0.250        2.250        2.250
# 39687               0.600           0.267        2.467        2.467
#
#        haptic.mask
# 33           2.000
# 102          2.211
# 107          2.286
# 280          2.176
# 380          2.909
# ...            ...
# 39538        2.188
# 39556        2.700
# 39637        2.421
# 39653        2.750
# 39687        2.133
#
# [828 rows x 9 columns]

# %%
sensory_dimentions_norms['haptic.mask']= sensory_dimentions_norms['Haptic.mean'][(sensory_dimentions_norms['Haptic.mean']<= 3)& (sensory_dimentions_norms['Haptic.mean']>=2)] 
sensory_dimentions_norms
# Out:
# /var/folders/tx/v15j42jn0y5dmzxnl_jrnhz80000gn/T/ipykernel_27007/3033110512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sensory_dimentions_norms['haptic.mask']= sensory_dimentions_norms['Haptic.mean'][(sensory_dimentions_norms['Haptic.mean']<= 3)& (sensory_dimentions_norms['Haptic.mean']>=2)]
#              Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 33       ABNORMAL          1.895           1.263        2.000
# 102    ABSORBENCY          0.158           0.053        2.211
# 107    ABSORPTION          0.714           0.714        2.286
# 280       ACQUIRE          0.824           0.647        2.176
# 380    ADHESIVELY          0.500           0.455        2.909
# ...           ...            ...             ...          ...
# 39538       WRUNG          0.875           0.000        2.188
# 39556        YANK          1.400           0.450        2.700
# 39637  YOURSELVES          2.474           1.316        2.421
# 39653         ZAP          2.100           0.050        2.750
# 39687        ZIPS          2.267           0.200        2.133
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  visual.mask  \
# 33                  2.053           1.526        3.000        3.000
# 102                 0.316           0.211        2.526        2.526
# 107                 2.071           0.357        3.000        3.000
# 280                 1.000           0.588        2.824        2.824
# 380                 0.182           0.318        2.000        2.000
# ...                   ...             ...          ...          ...
# 39538               0.125           0.000        2.375        2.375
# 39556               1.200           0.550        2.900        2.900
# 39637               2.737           1.737        3.000        3.000
# 39653               2.200           0.250        2.250        2.250
# 39687               0.600           0.267        2.467        2.467
#
#        haptic.mask
# 33           2.000
# 102          2.211
# 107          2.286
# 280          2.176
# 380          2.909
# ...            ...
# 39538        2.188
# 39556        2.700
# 39637        2.421
# 39653        2.750
# 39687        2.133
#
# [828 rows x 9 columns]

# %% [markdown]
# get rid of nan, how do we reduce this, ramdomized

# %%
sensory_dimentions_norms=sensory_dimentions_norms.dropna()

# %%
np.random.seed(8)
# fixes the starting point of randomization
# 8 becuase its my favorite number!

# %%
sensory_dimentions_norms_sample = sensory_dimentions_norms.sample(n=300)
sensory_dimentions_norms_sample
# Out:
#             Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 13240      FLUNG          0.800           0.000        2.400
# 28829    REWEAVE          0.133           0.000        2.067
# 36954    UNLOOSE          0.444           0.000        2.000
# 19318    KNOCKER          2.944           0.000        2.056
# 16681      HYMEN          0.176           0.000        2.294
# ...          ...            ...             ...          ...
# 19448     LANCES          0.375           0.000        2.062
# 3933      BREEZY          2.632           0.105        2.947
# 15788  HEAT PUMP          1.100           0.000        2.600
# 10655    EARPLUG          1.520           0.000        2.880
# 37690   UNWIELDY          1.235           0.647        2.000
#
#        Interoceptive.mean  Olfactory.mean  Visual.mean  visual.mask  \
# 13240               0.450           0.000        2.900        2.900
# 28829               0.067           0.067        2.600        2.600
# 36954               1.000           0.000        2.611        2.611
# 19318               0.278           0.000        2.667        2.667
# 16681               1.471           0.000        2.412        2.412
# ...                   ...             ...          ...          ...
# 19448               0.875           0.062        3.000        3.000
# 3933                1.368           0.632        2.316        2.316
# 15788               0.400           0.150        2.950        2.950
# 10655               0.440           0.040        2.600        2.600
# 37690               1.529           0.471        3.000        3.000
#
#        haptic.mask
# 13240        2.400
# 28829        2.067
# 36954        2.000
# 19318        2.056
# 16681        2.294
# ...            ...
# 19448        2.062
# 3933         2.947
# 15788        2.600
# 10655        2.880
# 37690        2.000
#
# [300 rows x 9 columns]

# %%
x_data = visual_sorted["Word"]
y_data = visual_sorted["Visual.mean"]
fig, ax = plt.subplots()
ax.plot(x_data, y_data)

ax.set(xlabel = 'Words', ylabel='Sensory strength (visual)',
       title = 'Lynott help me')
ax.get_xaxis().set_visible(False)
ax.grid()

# add verticle line
ax.axvline(x = 300, color = 'pink', linestyle = 'dotted', linewidth = 2)

#fig.savefig("test.png")
plt.show()

# %% [markdown]
# ****
# Work to do
#
# - add verticle line to over x axis after 300 words (visual and haptic)
# - make haptic plot for the 300 words in the dataframe
# - merge and filter for unquie occurance of words betweeen both list
# -

# %%
x_data = haptic_sorted["Word"]
y_data = haptic_sorted["Haptic.mean"]
fig, ax = plt.subplots()
ax.plot(x_data, y_data)

ax.set(xlabel = 'Words', ylabel='Haptic strength (haptic)',
       title = 'Clara help me')
ax.get_xaxis().set_visible(False)
ax.grid()

# add verticle line
ax.axvline(x = 300, color = 'orange', linestyle = 'dashed', linewidth = 2)

#fig.savefig("test.png")
plt.show()

# %% [markdown]
# **
# next to do
# - subset words (pandas dataframe)

# %%
visual_subset = visual_sorted.iloc[:300]
haptic_subset = haptic_sorted.iloc[:300]

# %%
visual_subset_df = pd.DataFrame(visual_subset)
visual_subset_df['mixed'] = 'visual'


haptic_subset_df = pd.DataFrame(haptic_subset)
haptic_subset_df['mixed'] = 'haptic'

haptic_subset_df

#haptic_subset['vishpt'] = 'haptic'

combined_visual_haptic_df = pd.concat([visual_subset_df, haptic_subset_df], ignore_index=True)
combined_visual_haptic_df
# Out:
#            Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 0     SIDE VIEW          0.000           0.000        0.000
# 1    BRIGHTNESS          0.235           0.235        0.176
# 2      BAR CODE          0.176           0.000        0.529
# 3           SEE          0.056           0.000        0.000
# 4        PRETTY          0.800           0.100        0.150
# ..          ...            ...             ...          ...
# 595       GRASP          1.158           0.000        3.947
# 596    SEATBELT          1.000           0.053        3.947
# 597   GENITALIA          0.842           1.421        3.947
# 598     PUSHING          0.526           0.158        3.947
# 599    MATERIAL          1.000           0.842        3.947
#
#      Interoceptive.mean  Olfactory.mean  Visual.mean   mixed
# 0                 0.529           0.000        5.000  visual
# 1                 0.824           0.176        5.000  visual
# 2                 0.000           0.000        5.000  visual
# 3                 0.333           0.000        5.000  visual
# 4                 1.100           0.600        5.000  visual
# ..                  ...             ...          ...     ...
# 595               1.421           0.000        2.368  haptic
# 596               0.421           0.105        3.579  haptic
# 597               2.158           1.737        4.158  haptic
# 598               1.789           0.158        3.474  haptic
# 599               0.842           1.105        3.947  haptic
#
# [600 rows x 8 columns]

# %%
unique_df = combined_visual_haptic_df.drop_duplicates(subset=['Word'])
unique_df # unique visual and haptic word mean
# Out:
#            Word  Auditory.mean  Gustatory.mean  Haptic.mean  \
# 0     SIDE VIEW          0.000           0.000        0.000
# 1    BRIGHTNESS          0.235           0.235        0.176
# 2      BAR CODE          0.176           0.000        0.529
# 3           SEE          0.056           0.000        0.000
# 4        PRETTY          0.800           0.100        0.150
# ..          ...            ...             ...          ...
# 595       GRASP          1.158           0.000        3.947
# 596    SEATBELT          1.000           0.053        3.947
# 597   GENITALIA          0.842           1.421        3.947
# 598     PUSHING          0.526           0.158        3.947
# 599    MATERIAL          1.000           0.842        3.947
#
#      Interoceptive.mean  Olfactory.mean  Visual.mean   mixed
# 0                 0.529           0.000        5.000  visual
# 1                 0.824           0.176        5.000  visual
# 2                 0.000           0.000        5.000  visual
# 3                 0.333           0.000        5.000  visual
# 4                 1.100           0.600        5.000  visual
# ..                  ...             ...          ...     ...
# 595               1.421           0.000        2.368  haptic
# 596               0.421           0.105        3.579  haptic
# 597               2.158           1.737        4.158  haptic
# 598               1.789           0.158        3.474  haptic
# 599               0.842           1.105        3.947  haptic
#
# [592 rows x 8 columns]

# %% [markdown]
# ****
#
# - slpit by value in a colum
# - box plot from column dataframe (5 plots) total 10 plot, 5 visual, 5 haptic

# %% [markdown]
# ****
# try again
# we want to make a new uniue column with high visual and haptic values
# the dataset is already in most to least visual
# we have to take the these value and compare them to the least to most haptic
# set a trheshold for both haptic and visual and create a new column with this to make it the visual-haptic column

# %% [markdown]
# search: how to mask data pandas within range
# answeres : df.where
# pandas, mask

# %% [markdown]
# *** next steps
#
# - plot visual , box plot, matplot (of each mean , all 5)
# - plot haptic , box plot, matplot (of each mean , all 5)
# - plot visual-haptic , box plot, matplot (of each mean , all 5)
# - try to join/merge them all other, stack
# - select column that we want (words, haptic, visual)
# - identify them, tag them, join/merge them
# - try to export dataframe as csv

# %%
# use combined_visual_haptic_df, where is my mixed? It is only plotting numerical plots 

column_to_plot = "Visual.mean"
fig, ax = plt.subplots()
data_to_plot = unique_df[column_to_plot]
boxes = ax.boxplot(data_to_plot, notch=True, vert=True, patch_artist=True) # Customize as needed

ax.set_xlabel(column_to_plot)
ax.set_ylabel('Values')
ax.set_title('Boxplot of ' + column_to_plot)
plt.show()

# %%
# use combined_visual_haptic_df, where is my mixed? It is only plotting numerical plots 

visual_column_to_plot = 'Visual.mean'

fig, ax = plt.subplots()
data_to_plot = sensory_dimentions_norms_sample['Visual.mean']
boxes = ax.boxplot(data_to_plot, notch=True, vert=True, patch_artist=True) # Customize as needed

ax.set_xlabel(visual_column_to_plot)
ax.set_ylabel('Values')
ax.set_title('Boxplot of ' + visual_column_to_plot)
plt.show()

# %%
#np.random.seed(1234)
np.random.seed(8)
# df = pd.DataFrame(np.random.randn(10, 4), columns=['Col1', 'Col2', 'Col3', 'Col4'])
unique_df = sensory_dimentions_norms(np.random.seed(8), columns=["Haptic.mean", "Auditory.mean"])
# boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3']) 
boxplot = df.boxplot(column=["Haptic.mean", "Auditory.mean"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 4
#       2 np.random.seed(8)
#       3 # df = pd.DataFrame(np.random.randn(10, 4), columns=['Col1', 'Col2', 'Col3', 'Col4'])
# ----> 4 unique_df = sensory_dimentions_norms(np.random.seed(8), columns=["Haptic.mean", "Auditory.mean"])
#       5 # boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
#       6 boxplot = df.boxplot(column=["Haptic.mean", "Auditory.mean"])
#
# TypeError: 'DataFrame' object is not callable
